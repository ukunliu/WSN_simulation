# %%
import osmium as osm
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import pyrosm

# %%
cw = pd.read_excel('./simulation/simulation géoloc/data_sim_NY.xlsx', 'sim1_NY')
hk = pd.read_excel('./simulation/simulation géoloc/data_sim_NY.xlsx', 'sim2_NY')
nyc = pd.read_excel('./simulation/simulation géoloc/data_sim_NY.xlsx', 'sim3_NY')

# %%
cw.head()
# Out:
#        rssi_bs1      rssi_bs2      rssi_bs3       lon        lat
# 0    -66.479528    -67.474128    -55.007897  0.019537  51.502845
# 1    -64.671813  65535.000000    -58.917959  0.019764  51.503350
# 2    -60.545631    -61.587014    -68.405088  0.017817  51.503319
# 3  65535.000000  65535.000000  65535.000000  0.019783  51.502703
# 4  65535.000000  65535.000000  65535.000000  0.019081  51.502649

# %%
hk.head()
# Out:
#        rssi_bs1      rssi_bs2      rssi_bs3      rssi_bs4      rssi_bs5  \
# 0    -66.479528    -67.474128    -55.007897    -66.479528    -67.474128
# 1    -64.671813  65535.000000    -58.917959    -64.671813  65535.000000
# 2    -60.545631    -61.587014    -68.405088    -60.545631    -61.587014
# 3  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
# 4  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
#
#        rssi_bs6      rssi_bs7      rssi_bs8      rssi_bs9     rssi_bs10  \
# 0    -55.007897    -66.479528    -67.474128    -55.007897    -66.479528
# 1    -58.917959    -64.671813  65535.000000    -58.917959    -64.671813
# 2    -68.405088    -60.545631    -61.587014    -68.405088    -60.545631
# 3  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
# 4  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
#
#       rssi_bs11     rssi_bs12       lon        lat
# ...

# %%
nyc.head()
# Out:
#        rssi_bs1      rssi_bs2      rssi_bs3      rssi_bs4      rssi_bs5  \
# 0    -66.479528    -67.474128    -55.007897    -66.479528    -67.474128
# 1    -64.671813  65535.000000    -58.917959    -64.671813  65535.000000
# 2    -60.545631    -61.587014    -68.405088    -60.545631    -61.587014
# 3  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
# 4  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
#
#        rssi_bs6      rssi_bs7      rssi_bs8      rssi_bs9     rssi_bs10  \
# 0    -55.007897    -66.479528    -67.474128    -55.007897    -66.479528
# 1    -58.917959    -64.671813  65535.000000    -58.917959    -64.671813
# 2    -68.405088    -60.545631    -61.587014    -68.405088    -60.545631
# 3  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
# 4  65535.000000  65535.000000  65535.000000  65535.000000  65535.000000
#
#       rssi_bs11     rssi_bs12       lon        lat
# ...

# %%
plt.scatter(cw['lon'], cw['lat'])
plt.scatter(hk['lon'], hk['lat'])
plt.scatter(nyc['lon'], nyc['lat'])

# %% [markdown]
# ## Read .osm
